# %% [markdown]
# # Open System Diagram in drawio or diagrams.net

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # From the menu select File, Export as SVG

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Click on Export, using default settings; Select Folder Location where to export, and remove .drawio name extension before exporting to folder

# %% [markdown]
# ![image.png](attachment:image.png)
