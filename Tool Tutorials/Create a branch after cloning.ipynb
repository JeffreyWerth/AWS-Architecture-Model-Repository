# %% [markdown]
# # Go to your project repository on GitHub Online

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Click on the Branch menu, and then click on New Branch green bottom

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Name your branch (project_branch), and click on Create branch

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Go to the project_branch, by clicking on the link for the project_branch under Active branches list

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Now you can see that you are in the project_branch, and you have two branches for the project repository (main and project_branch)

# %% [markdown]
# ![image.png](attachment:image.png)
