# %% [markdown]
# Navigate to Project Repository (https://github.com/kentmichae/AWS-Architecture-Model-Repository)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Select <Code> Local Clone menu, you have three options to Open with GitHub Desktop, Open with Visual Studio or Download ZIP

# %% [markdown]
# ![image.png](attachment:image.png)
