# %% [markdown]
# # Open System Diagram in drwio or diagrams.net

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # From the menu select File, Export as SVG

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Click on Export, using default settings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Select Folder Location where to export, and remove .drwio name extension before exporting to folder
