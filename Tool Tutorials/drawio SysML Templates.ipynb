# %% [markdown]
# # Opening draw.io from diagrams.net, go to the site by link (https://www.diagrams.net/blog/embed-diagrams-github-markdown)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Click on Start Now on top righ corner of Browser Window, and select media to save diagrams to:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # To use GitHUb Repository Package, click on the GitHub Icon, and click Create New Diagram

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Select Blank Diagram Template to Start

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Select Folder that will be your Project Package

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sekect a Commit Message to create the diagram in your Package

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # To Use the SysML Templates, click on the lower left corner +More Shapes and Browse Down to SyML Library and hit apply

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # To Selec a Model Element, just click on top of the item to select and add to your diagram view

# %% [markdown]
# ![image.png](attachment:image.png)
